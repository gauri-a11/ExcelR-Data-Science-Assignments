# %% [markdown]
# # Artificial Neural networks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data=pd.read_csv('Alphabets_data.csv')
data
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %% [markdown]
# # Data Exploration and Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  str
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), str(1)
# memory usage: 2.6 MB

# %%
data.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
data.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
data.hist(bins=20,figsize=(15,11))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
le=LabelEncoder()

# %%
data['letter']=le.fit_transform(data['letter'])

# %%
features=data.drop('letter',axis=1)

# %%
se=StandardScaler()
se.fit_transform(features)
# Out:
# array([[-1.0576983 ,  0.29187713, -1.05327668, ..., -0.21908163,
#         -1.4381527 ,  0.12291107],
#        [ 0.51038497,  1.5023577 , -1.05327668, ..., -0.21908163,
#          0.12008142,  1.35944092],
#        [-0.01230945,  1.19973756,  0.43590966, ..., -0.8656262 ,
#         -0.26947711,  0.74117599],
#        ...,
#        [ 1.03307939,  0.59449727,  0.43590966, ...,  2.36709667,
#         -0.65903564, -2.35014863],
#        [-1.0576983 , -1.22122359, -0.55688123, ...,  0.42746295,
#          0.50963994,  0.12291107],
#        [-0.01230945,  0.59449727,  0.43590966, ..., -0.8656262 ,
#         -0.65903564,  0.12291107]], shape=(20000, 16))

# %%
target=data['letter']

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Model Implementation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import keras_tuner as kt

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',   
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    x_train,
    y_train,
    validation_split=0.33,
    epochs=20,
    batch_size=20
)
# Out:
# Epoch 1/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0369 - loss: -227121.7031 - val_accuracy: 0.0411 - val_loss: -963333.9375
# Epoch 2/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -3768707.7500 - val_accuracy: 0.0411 - val_loss: -7966114.0000
# Epoch 3/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -15517951.0000 - val_accuracy: 0.0411 - val_loss: -24876300.0000
# Epoch 4/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -38536568.0000 - val_accuracy: 0.0411 - val_loss: -54116208.0000
# Epoch 5/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -74439648.0000 - val_accuracy: 0.0411 - val_loss: -96704896.0000
# Epoch 6/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -124362248.0000 - val_accuracy: 0.0411 - val_loss: -153833152.0000
# Epoch 7/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -189390016.0000 - val_accuracy: 0.0411 - val_loss: -226473824.0000
# Epoch 8/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -270506944.0000 - val_accuracy: 0.0411 - val_loss: -315506176.0000
# Epoch 9/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -368458016.0000 - val_accuracy: 0.0411 - val_loss: -421871616.0000
# Epoch 10/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -483957920.0000 - val_accuracy: 0.0411 - val_loss: -546006912.0000
# Epoch 11/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -618160448.0000 - val_accuracy: 0.0411 - val_loss: -689374464.0000
# Epoch 12/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -771540608.0000 - val_accuracy: 0.0411 - val_loss: -851952128.0000
# Epoch 13/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -945363584.0000 - val_accuracy: 0.0411 - val_loss: -1036128576.0000
# Epoch 14/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -1140688128.0000 - val_accuracy: 0.0411 - val_loss: -1241463296.0000
# Epoch 15/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -1357747968.0000 - val_accuracy: 0.0411 - val_loss: -1468895104.0000
# Epoch 16/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -1598254080.0000 - val_accuracy: 0.0411 - val_loss: -1720545664.0000
# Epoch 17/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -1863145344.0000 - val_accuracy: 0.0411 - val_loss: -1996893696.0000
# Epoch 18/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -2152534016.0000 - val_accuracy: 0.0411 - val_loss: -2297854720.0000
# Epoch 19/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -2467892736.0000 - val_accuracy: 0.0411 - val_loss: -2625743104.0000
# Epoch 20/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0369 - loss: -2809894144.0000 - val_accuracy: 0.0411 - val_loss: -2979836672.0000

# %%
score=model.evaluate(x_train,y_train)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0383 - loss: -2986834176.0000

# %%
score
# Out:
# [-2986834176.0, 0.03831249848008156]

# %% [markdown]
# # Hyperparameter Tuning

# %%
# !pip install tensorflow keras-tuner
# Out:
# Requirement already satisfied: tensorflow in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (2.21.0)
# Requirement already satisfied: keras-tuner in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (1.4.8)
# Requirement already satisfied: absl-py>=1.0.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: kt-legacy in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import keras_tuner as kt

def build_model(hp):
    model = Sequential()
    
    model.add(
        Dense(
            units=hp.Int('units1', min_value=32, max_value=128, step=16),
            activation='relu',
            input_shape=(x_train.shape[1],)
        )
    )
    
    model.add(
        Dense(
            units=hp.Int('units2', min_value=16, max_value=64, step=16),
            activation='relu'
        )
    )
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])
        ),
        loss='binary_crossentropy',   # <-- FIXED
        metrics=['accuracy']
    )
    
    return model

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (2.4.4)
# Requirement already satisfied: packaging in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (12.1.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (7.34.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (82.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from tensorboard) (3.1.7)
# Requirement already satisfied: typing-extensions~=4.12 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)

# %%
tuner = kt.RandomSearch(build_model, objective='val_accuracy', max_trials=5, executions_per_trial=3, directory='my_dir', project_name='alphabet_tuning')

tuner.search(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Trial 5 Complete [00h 01m 44s]
# val_accuracy: 0.04312499985098839
#
# Best val_accuracy So Far: 0.04312499985098839
# Total elapsed time: 01h 55m 52s

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best units1: {best_hps.get('units1')}, Best units2: {best_hps.get('units2')}, Best learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Best units1: 96, Best units2: 48, Best learning_rate: 0.001

# %%
best_model = tuner.hypermodel.build(best_hps)

# %%
best_model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.0347 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0372 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0367 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0346 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0370 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.0355 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0373 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0358 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0360 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0380 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0378 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0369 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0326 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0377 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.0382 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0369 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.0374 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0397 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0370 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0373 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0377 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0359 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0359 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0384 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0358 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0363 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0392 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0369 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0357 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0394 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0358 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0415 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0353 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0376 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0380 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0355 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0383 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0354 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0360 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.0392 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0384 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0368 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0394 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.0375 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.0358 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0360 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0392 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0377 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0369 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00

# %% [markdown]
# # Evaluation

# %%
test_loss, test_accuracy = best_model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0382 - loss: -31.3367
# Test Accuracy: 0.03824999928474426
