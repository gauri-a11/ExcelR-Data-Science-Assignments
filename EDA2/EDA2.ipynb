# %% [markdown]
# # EDA2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # 1. Data Exploration and Preprocessing:

# %%
data=pd.read_csv('adult_with_headers.csv')

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  str
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  str
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  str
#  6   occupation      32561 non-null  str
#  7   relationship    32561 non-null  str
#  8   race            32561 non-null  str
#  9   sex             32561 non-null  str
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  str
#  14  income          32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
numaric_cols=data.select_dtypes(include=[int,float]).columns

# %%
numaric_cols
# Out:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='str')

# %%
stdscaler=StandardScaler()
minmax=MinMaxScaler()

# %%
dfstd=stdscaler.fit_transform(data[numaric_cols])
dfstd=pd.DataFrame(dfstd,columns=numaric_cols)
dfmm=minmax.fit_transform(data[numaric_cols])
dfmm=pd.DataFrame(dfmm,columns=numaric_cols)

# %%
dfstd
# Out:
#             age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      0.030671 -1.063611       1.134739      0.148453      -0.21666
# 1      0.837109 -1.008707       1.134739     -0.145920      -0.21666
# 2     -0.042642  0.245079      -0.420060     -0.145920      -0.21666
# 3      1.057047  0.425801      -1.197459     -0.145920      -0.21666
# 4     -0.775768  1.408176       1.134739     -0.145920      -0.21666
# ...         ...       ...            ...           ...           ...
# 32556 -0.849080  0.639741       0.746039     -0.145920      -0.21666
# 32557  0.103983 -0.335433      -0.420060     -0.145920      -0.21666
# 32558  1.423610 -0.358777      -0.420060     -0.145920      -0.21666
# 32559 -1.215643  0.110960      -0.420060     -0.145920      -0.21666
# 32560  0.983734  0.929893      -0.420060      1.888424      -0.21666
#
#        hours_per_week
# 0           -0.035429
# 1           -2.222153
# 2           -0.035429
# 3           -0.035429
# 4           -0.035429
# ...               ...
# 32556       -0.197409
# 32557       -0.035429
# 32558       -0.035429
# 32559       -1.655225
# 32560       -0.035429
#
# [32561 rows x 6 columns]

# %%
dfmm
# Out:
#             age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      0.301370  0.044302       0.800000      0.021740           0.0
# 1      0.452055  0.048238       0.800000      0.000000           0.0
# 2      0.287671  0.138113       0.533333      0.000000           0.0
# 3      0.493151  0.151068       0.400000      0.000000           0.0
# 4      0.150685  0.221488       0.800000      0.000000           0.0
# ...         ...       ...            ...           ...           ...
# 32556  0.136986  0.166404       0.733333      0.000000           0.0
# 32557  0.315068  0.096500       0.533333      0.000000           0.0
# 32558  0.561644  0.094827       0.533333      0.000000           0.0
# 32559  0.068493  0.128499       0.533333      0.000000           0.0
# 32560  0.479452  0.187203       0.533333      0.150242           0.0
#
#        hours_per_week
# 0            0.397959
# 1            0.122449
# 2            0.397959
# 3            0.397959
# 4            0.397959
# ...               ...
# 32556        0.377551
# 32557        0.397959
# 32558        0.397959
# 32559        0.193878
# 32560        0.397959
#
# [32561 rows x 6 columns]

# %%
dfstd.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  3.256100e+04  3.256100e+04   3.256100e+04  3.256100e+04  3.256100e+04
# mean  -2.662271e-17 -9.732565e-17   1.479525e-16  5.237255e-18 -4.364379e-17
# std    1.000015e+00  1.000015e+00   1.000015e+00  1.000015e+00  1.000015e+00
# min   -1.582206e+00 -1.681631e+00  -3.529656e+00 -1.459205e-01 -2.166595e-01
# 25%   -7.757679e-01 -6.816910e-01  -4.200596e-01 -1.459205e-01 -2.166595e-01
# 50%   -1.159546e-01 -1.082193e-01  -3.136003e-02 -1.459205e-01 -2.166595e-01
# 75%    6.904838e-01  4.478765e-01   7.460392e-01 -1.459205e-01 -2.166595e-01
# max    3.769612e+00  1.226856e+01   2.300838e+00  1.339458e+01  1.059351e+01
#
#        hours_per_week
# count    3.256100e+04
# mean    -2.574984e-17
# std      1.000015e+00
# min     -3.194030e+00
# 25%     -3.542945e-02
# 50%     -3.542945e-02
# 75%      3.695194e-01
# max      4.742967e+00

# %%
dfmm.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  32561.000000   32561.000000  32561.000000  32561.000000
# mean       0.295639      0.120545       0.605379      0.010777      0.020042
# std        0.186855      0.071685       0.171515      0.073854      0.092507
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        0.150685      0.071679       0.533333      0.000000      0.000000
# 50%        0.273973      0.112788       0.600000      0.000000      0.000000
# 75%        0.424658      0.152651       0.733333      0.000000      0.000000
# max        1.000000      1.000000       1.000000      1.000000      1.000000
#
#        hours_per_week
# count    32561.000000
# mean         0.402423
# std          0.125994
# min          0.000000
# 25%          0.397959
# 50%          0.397959
# 75%          0.448980
# max          1.000000

# %% [markdown]
# ### Discuss the scenarios where each scaling technique is preferred and why.
# ##### Standardization:
#     Preferred when data is normally distributed or when the algorithm assumes a Gaussian distribution.
# ##### Normalization (Min-Max Scaling):
#     Preferred when data needs to be bounded within a specific range (e.g., [0, 1] or [-1, 1]).

# %% [markdown]
# # 2. Encoding Techniques:

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
categorical_cols=data.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='str')

# %%
for col in categorical_cols:
    b=data[col].unique()
    print(f'{col} had {b}','\n')
# Out:
# workclass had <StringArray>
# [       ' State-gov', ' Self-emp-not-inc',          ' Private',
#       ' Federal-gov',        ' Local-gov',                ' ?',
#      ' Self-emp-inc',      ' Without-pay',     ' Never-worked']
# Length: 9, dtype: str
#
# education had <StringArray>
# [   ' Bachelors',      ' HS-grad',         ' 11th',      ' Masters',
#           ' 9th', ' Some-college',   ' Assoc-acdm',    ' Assoc-voc',
#       ' 7th-8th',    ' Doctorate',  ' Prof-school',      ' 5th-6th',
#          ' 10th',      ' 1st-4th',    ' Preschool',         ' 12th']
# Length: 16, dtype: str
#
# marital_status had <StringArray>
# [        ' Never-married',    ' Married-civ-spouse',              ' Divorced',
#  ' Married-spouse-absent',             ' Separated',     ' Married-AF-spouse',
#                ' Widowed']
# Length: 7, dtype: str
#
# occupation had <StringArray>
# [     ' Adm-clerical',   ' Exec-managerial', ' Handlers-cleaners',
#     ' Prof-specialty',     ' Other-service',             ' Sales',
#       ' Craft-repair',  ' Transport-moving',   ' Farming-fishing',
#  ' Machine-op-inspct',      ' Tech-support',                 ' ?',
#    ' Protective-serv',      ' Armed-Forces',   ' Priv-house-serv']
# Length: 15, dtype: str
#
# relationship had <StringArray>
# [ ' Not-in-family',        ' Husband',           ' Wife',      ' Own-child',
#       ' Unmarried', ' Other-relative']
# Length: 6, dtype: str
#
# race had <StringArray>
# [' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other']
# Length: 5, dtype: str
#
# sex had <StringArray>
# [' Male', ' Female']
# Length: 2, dtype: str
#
# native_country had <StringArray>
# [             ' United-States',                       ' Cuba',
#                     ' Jamaica',                      ' India',
#                           ' ?',                     ' Mexico',
#                       ' South',                ' Puerto-Rico',
#                    ' Honduras',                    ' England',
#                      ' Canada',                    ' Germany',
#                        ' Iran',                ' Philippines',
#                       ' Italy',                     ' Poland',
#                    ' Columbia',                   ' Cambodia',
#                    ' Thailand',                    ' Ecuador',
#                        ' Laos',                     ' Taiwan',
#                       ' Haiti',                   ' Portugal',
#          ' Dominican-Republic',                ' El-Salvador',
#                      ' France',                  ' Guatemala',
#                       ' China',                      ' Japan',
#                  ' Yugoslavia',                       ' Peru',
#  ' Outlying-US(Guam-USVI-etc)',                   ' Scotland',
#             ' Trinadad&Tobago',                     ' Greece',
#                   ' Nicaragua',                    ' Vietnam',
#                        ' Hong',                    ' Ireland',
#                     ' Hungary',         ' Holand-Netherlands']
# Length: 42, dtype: str
#
# income had <StringArray>
# [' <=50K', ' >50K']
# Length: 2, dtype: str

# %%
onehot=OneHotEncoder()

# %%
dummies = pd.get_dummies(data[['sex','income']],dtype=int)

# %%
dummies
# Out:
#        sex_ Female  sex_ Male  income_ <=50K  income_ >50K
# 0                0          1              1             0
# 1                0          1              1             0
# 2                0          1              1             0
# 3                0          1              1             0
# 4                1          0              1             0
# ...            ...        ...            ...           ...
# 32556            1          0              1             0
# 32557            0          1              0             1
# 32558            1          0              1             0
# 32559            0          1              1             0
# 32560            1          0              0             1
#
# [32561 rows x 4 columns]

# %%
label=LabelEncoder()

# %%
data['education'] = label.fit_transform(data['education'])
data['workclass'] = label.fit_transform(data['workclass'])
data['marital_status'] = label.fit_transform(data['marital_status'])
data['occupation'] = label.fit_transform(data['occupation'])
data['relationship'] = label.fit_transform(data['relationship'])
data['race'] = label.fit_transform(data['race'])
data['native_country'] = label.fit_transform(data['native_country'])

# %%
data.drop(data[['sex','income']],axis=1,inplace=True)

# %%
data=data.join(dummies,how='right')

# %%
data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  capital_loss  \
# 0               1             1     4          2174             0
# 1               4             0     4             0             0
# 2               6             1     4             0             0
# 3               6             0     2             0             0
# 4              10             5     2             0             0
# ...           ...           ...   ...           ...           ...
# 32556          13             5     4             0             0
# 32557           7             0     4             0             0
# 32558           1             4     4             0             0
# 32559           1             3     4             0             0
# 32560           4             5     4         15024             0
#
#        hours_per_week  native_country  sex_ Female  sex_ Male  income_ <=50K  \
# 0                  40              39            0          1              1
# 1                  13              39            0          1              1
# 2                  40              39            0          1              1
# 3                  40              39            0          1              1
# 4                  40               5            1          0              1
# ...               ...             ...          ...        ...            ...
# 32556              38              39            1          0              1
# 32557              40              39            0          1              0
# 32558              40              39            1          0              1
# 32559              20              39            0          1              1
# 32560              40              39            1          0              0
#
#        income_ >50K
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 32556             0
# 32557             1
# 32558             0
# 32559             0
# 32560             1
#
# [32561 rows x 17 columns]

# %%
data.describe()
# Out:
#                 age     workclass        fnlwgt     education  education_num  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000   32561.000000
# mean      38.581647      3.868892  1.897784e+05     10.298210      10.080679
# std       13.640433      1.455960  1.055500e+05      3.870264       2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178270e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783560e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370510e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital_status    occupation  relationship          race  capital_gain  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         2.611836      6.572740      1.446362      3.665858   1077.648844
# std          1.506222      4.228857      1.606771      0.848806   7385.292085
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      3.000000      0.000000      4.000000      0.000000
# 50%          2.000000      7.000000      1.000000      4.000000      0.000000
# 75%          4.000000     10.000000      3.000000      4.000000      0.000000
# max          6.000000     14.000000      5.000000      4.000000  99999.000000
#
#        capital_loss  hours_per_week  native_country   sex_ Female  \
# count  32561.000000    32561.000000    32561.000000  32561.000000
# mean      87.303830       40.437456       36.718866      0.330795
# std      402.960219       12.347429        7.823782      0.470506
# min        0.000000        1.000000        0.000000      0.000000
# 25%        0.000000       40.000000       39.000000      0.000000
# 50%        0.000000       40.000000       39.000000      0.000000
# 75%        0.000000       45.000000       39.000000      1.000000
# max     4356.000000       99.000000       41.000000      1.000000
#
#           sex_ Male  income_ <=50K  income_ >50K
# count  32561.000000   32561.000000  32561.000000
# mean       0.669205       0.759190      0.240810
# std        0.470506       0.427581      0.427581
# min        0.000000       0.000000      0.000000
# 25%        0.000000       1.000000      0.000000
# 50%        1.000000       1.000000      0.000000
# 75%        1.000000       1.000000      0.000000
# max        1.000000       1.000000      1.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int64
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  int64
#  6   occupation      32561 non-null  int64
#  7   relationship    32561 non-null  int64
#  8   race            32561 non-null  int64
#  9   capital_gain    32561 non-null  int64
#  10  capital_loss    32561 non-null  int64
#  11  hours_per_week  32561 non-null  int64
#  12  native_country  32561 non-null  int64
#  13  sex_ Female     32561 non-null  int64
#  14  sex_ Male       32561 non-null  int64
#  15  income_ <=50K   32561 non-null  int64
#  16  income_ >50K    32561 non-null  int64
# dtypes: int64(17)
# memory usage: 4.2 MB

# %% [markdown]
# # 3. Feature Engineering:

# %%
# Create new features
data['capital-gain-minus-loss'] = data['capital_gain'] - data['capital_loss']
data['age_squared'] = data['age'] ** 2

# %%
data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  capital_loss  \
# 0               1             1     4          2174             0
# 1               4             0     4             0             0
# 2               6             1     4             0             0
# 3               6             0     2             0             0
# 4              10             5     2             0             0
# ...           ...           ...   ...           ...           ...
# 32556          13             5     4             0             0
# 32557           7             0     4             0             0
# 32558           1             4     4             0             0
# 32559           1             3     4             0             0
# 32560           4             5     4         15024             0
#
#        hours_per_week  native_country  sex_ Female  sex_ Male  income_ <=50K  \
# 0                  40              39            0          1              1
# 1                  13              39            0          1              1
# 2                  40              39            0          1              1
# 3                  40              39            0          1              1
# 4                  40               5            1          0              1
# ...               ...             ...          ...        ...            ...
# 32556              38              39            1          0              1
# 32557              40              39            0          1              0
# 32558              40              39            1          0              1
# 32559              20              39            0          1              1
# 32560              40              39            1          0              0
#
#        income_ >50K  capital-gain-minus-loss  age_squared
# 0                 0                     2174         1521
# 1                 0                        0         2500
# 2                 0                        0         1444
# 3                 0                        0         2809
# 4                 0                        0          784
# ...             ...                      ...          ...
# 32556             0                        0          729
# 32557             1                        0         1600
# 32558             0                        0         3364
# 32559             0                        0          484
# 32560             1                    15024         2704
#
# [32561 rows x 19 columns]

# %%
data['capital-gain_log'] = np.log1p(data['capital_gain'])

# %%
data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  capital_loss  \
# 0               1             1     4          2174             0
# 1               4             0     4             0             0
# 2               6             1     4             0             0
# 3               6             0     2             0             0
# 4              10             5     2             0             0
# ...           ...           ...   ...           ...           ...
# 32556          13             5     4             0             0
# 32557           7             0     4             0             0
# 32558           1             4     4             0             0
# 32559           1             3     4             0             0
# 32560           4             5     4         15024             0
#
#        hours_per_week  native_country  sex_ Female  sex_ Male  income_ <=50K  \
# 0                  40              39            0          1              1
# 1                  13              39            0          1              1
# 2                  40              39            0          1              1
# 3                  40              39            0          1              1
# 4                  40               5            1          0              1
# ...               ...             ...          ...        ...            ...
# 32556              38              39            1          0              1
# 32557              40              39            0          1              0
# 32558              40              39            1          0              1
# 32559              20              39            0          1              1
# 32560              40              39            1          0              0
#
#        income_ >50K  capital-gain-minus-loss  age_squared  capital-gain_log
# 0                 0                     2174         1521          7.684784
# 1                 0                        0         2500          0.000000
# 2                 0                        0         1444          0.000000
# 3                 0                        0         2809          0.000000
# 4                 0                        0          784          0.000000
# ...             ...                      ...          ...               ...
# 32556             0                        0          729          0.000000
# 32557             1                        0         1600          0.000000
# 32558             0                        0         3364          0.000000
# 32559             0                        0          484          0.000000
# 32560             1                    15024         2704          9.617471
#
# [32561 rows x 20 columns]

# %% [markdown]
# # 4. Feature Selection:

# %%
from sklearn.ensemble import IsolationForest

# %%
ift=IsolationForest(random_state=10,contamination=0.1)

# %%
ift.fit(data)
# Out:
# IsolationForest(contamination=0.1, random_state=10)

# %%
outliers=pd.DataFrame(ift.predict(data))

# %%
outliers.columns = ['outliers']

# %%
data=data.join(outliers,how='right')

# %%
data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  ...  hours_per_week  \
# 0               1             1     4          2174  ...              40
# 1               4             0     4             0  ...              13
# 2               6             1     4             0  ...              40
# 3               6             0     2             0  ...              40
# 4              10             5     2             0  ...              40
# ...           ...           ...   ...           ...  ...             ...
# 32556          13             5     4             0  ...              38
# 32557           7             0     4             0  ...              40
# 32558           1             4     4             0  ...              40
# 32559           1             3     4             0  ...              20
# 32560           4             5     4         15024  ...              40
#
#        native_country  sex_ Female  sex_ Male  income_ <=50K  income_ >50K  \
# 0                  39            0          1              1             0
# 1                  39            0          1              1             0
# 2                  39            0          1              1             0
# 3                  39            0          1              1             0
# 4                   5            1          0              1             0
# ...               ...          ...        ...            ...           ...
# 32556              39            1          0              1             0
# 32557              39            0          1              0             1
# 32558              39            1          0              1             0
# 32559              39            0          1              1             0
# 32560              39            1          0              0             1
#
#        capital-gain-minus-loss  age_squared  capital-gain_log  outliers
# 0                         2174         1521          7.684784         1
# 1                            0         2500          0.000000         1
# 2                            0         1444          0.000000         1
# 3                            0         2809          0.000000         1
# 4                            0          784          0.000000        -1
# ...                        ...          ...               ...       ...
# 32556                        0          729          0.000000         1
# 32557                        0         1600          0.000000         1
# 32558                        0         3364          0.000000         1
# 32559                        0          484          0.000000         1
# 32560                    15024         2704          9.617471        -1
#
# [32561 rows x 21 columns]

# %%
data[data['outliers']==-1]
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 4       28          4  338409          9             13               2
# 8       31          4   45781         12             14               4
# 27      54          0  180211         15             10               2
# 52      47          4   51835         14             15               2
# 61      32          0  293936          5              4               3
# ...    ...        ...     ...        ...            ...             ...
# 32538   38          4  139180          9             13               0
# 32539   71          0  287372         10             16               2
# 32545   39          2  111499          7             12               2
# 32548   65          6   99359         14             15               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  capital_gain  ...  hours_per_week  \
# 4              10             5     2             0  ...              40
# 8              10             1     4         14084  ...              50
# 27              0             0     1             0  ...              60
# 52             10             5     4             0  ...              60
# 61              0             1     4             0  ...              40
# ...           ...           ...   ...           ...  ...             ...
# 32538          10             4     2         15020  ...              45
# 32539           0             0     4             0  ...              10
# 32545           1             5     4             0  ...              20
# 32548          10             1     4          1086  ...              60
# 32560           4             5     4         15024  ...              40
#
#        native_country  sex_ Female  sex_ Male  income_ <=50K  income_ >50K  \
# 4                   5            1          0              1             0
# 8                  39            1          0              0             1
# 27                 35            0          1              0             1
# 52                 16            1          0              0             1
# 61                  0            0          1              1             0
# ...               ...          ...        ...            ...           ...
# 32538              39            1          0              0             1
# 32539              39            0          1              0             1
# 32545              39            1          0              0             1
# 32548              39            0          1              1             0
# 32560              39            1          0              0             1
#
#        capital-gain-minus-loss  age_squared  capital-gain_log  outliers
# 4                            0          784          0.000000        -1
# 8                        14084          961          9.552866        -1
# 27                           0         2916          0.000000        -1
# 52                       -1902         2209          0.000000        -1
# 61                           0         1024          0.000000        -1
# ...                        ...          ...               ...       ...
# 32538                    15020         1444          9.617205        -1
# 32539                        0         5041          0.000000        -1
# 32545                        0         1521          0.000000        -1
# 32548                     1086         4225          6.991177        -1
# 32560                    15024         2704          9.617471        -1
#
# [3256 rows x 21 columns]

# %%
# !pip install ppscore
# Out:
# Requirement already satisfied: ppscore in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (1.3.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from ppscore) (3.0.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from ppscore) (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from pandas>=1.0.0->ppscore) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from pandas>=1.0.0->ppscore) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Gauri\DataScience1\Assignment\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ppscore) (1.17.0)

# %%
import ppscore as pps

# %%
pps.score(data,'age','income_ >50K')
# Out:
# {'x': 'age',
#  'y': 'income_ >50K',
#  'ppscore': 0,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 0.2424,
#  'model_score': np.float64(0.32837761728313286),
#  'model': DecisionTreeRegressor()}

# %%
pps.matrix(data)
# Out:
#             x                        y  ppscore            case  \
# 0         age                      age      1.0  predict_itself
# 1         age                workclass      0.0      regression
# 2         age                   fnlwgt      0.0      regression
# 3         age                education      0.0      regression
# 4         age            education_num      0.0      regression
# ..        ...                      ...      ...             ...
# 436  outliers             income_ >50K      0.0      regression
# 437  outliers  capital-gain-minus-loss      0.0      regression
# 438  outliers              age_squared      0.0      regression
# 439  outliers         capital-gain_log      0.0      regression
# 440  outliers                 outliers      1.0  predict_itself
#
#      is_valid_score               metric  baseline_score   model_score  \
# 0              True                  NaN        0.000000      1.000000
# 1              True  mean absolute error        0.742600      0.875681
# 2              True  mean absolute error    75872.186200  77535.141544
# 3              True  mean absolute error        2.759000      2.806164
# 4              True  mean absolute error        1.853000      1.898306
# ..              ...                  ...             ...           ...
# 436            True  mean absolute error        0.242400      0.343314
# 437            True  mean absolute error     1188.826600   1535.460754
# 438            True  mean absolute error      897.468600    907.468831
# 439            True  mean absolute error        0.714858      1.021794
# 440            True                  NaN        0.000000      1.000000
#
#                        model
# 0                       None
# 1    DecisionTreeRegressor()
# 2    DecisionTreeRegressor()
# 3    DecisionTreeRegressor()
# 4    DecisionTreeRegressor()
# ..                       ...
# 436  DecisionTreeRegressor()
# 437  DecisionTreeRegressor()
# 438  DecisionTreeRegressor()
# 439  DecisionTreeRegressor()
# 440                     None
#
# [441 rows x 9 columns]
