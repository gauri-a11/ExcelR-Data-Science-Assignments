# %% [markdown]
# Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
number=int(input("enter number to check prime or not"))
if number<=1:
    print("not prime")
elif(number==2):
    print("prime")
elif(number%2==0):
    print("not prime")
else:
    for i in range(3,number//2+1):
        if number%i==0:
            print("not prime")
            break
    else:
        print("prime")
# Out:
# not prime

# %% [markdown]
# Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
num1=random.randint(1,20)
num2=random.randint(1,20)
print(f"{num1} , {num2}")
user_ans=int(input("find product"))
answer=num1*num2
if answer==user_ans:
    print("correct")
else:
    print("wrong")
# Out:
# 2 , 20
# wrong

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
choice=input("even or odd")
min=int(input("enter min range"))
max=int(input("enter max range"))
if choice =="even":
    for i in range (min,max+1):
        if i%2==0:
            print(i*i)
elif choice=="odd":
    for i in range(min,max+1):
        if i%2!=0:
            print(i*i)
# Out:
# 400
# 484
# 576
# 676
# 784
# 900
# 1024
# 1156
# 1296
# 1444
# 1600
# 1764
# 1936

# %% [markdown]
# Exercise 4: Word counter
#
# write a program to count the number of words in a given text.

# %%
my_string=str(input("Enter string to count words"))
my_string=my_string.lower()
punctuation='''!()-[]{}:;"'\@.<>,/?#$%^&*_~'''
count={}
for char in punctuation:
    my_string=my_string.replace(char,"")

for i in my_string.split():
    if i in count:
      count[i]+=1
    else:
       count[i]=1  
print(count)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\@'
# <>:3: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\Gauri\AppData\Local\Temp\ipykernel_7716\3219481774.py:3: SyntaxWarning: invalid escape sequence '\@'
#   punctuation='''!()-[]{}:;"'\@.<>,/?#$%^&*_~'''
# {'hello': 1, 'how': 1, 'are': 1, 'you': 1}

# %% [markdown]
# Exercise 5: Check for Palindrome
#
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
def isPalindrome(n):
    n1=n[::-1]
    if(n1==n):
        print("palindrome")
    else:
        print("no")  

n=input()
isPalindrome(n)
# Out:
# palindrome
